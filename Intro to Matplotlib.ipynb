# %% [markdown]
# # Intro to matplotlib
#
# ## Fast Graphs
# Code to make graphs using matplotlib in a fast way

# %%
year = [2010, 2012, 2014, 2016, 2018]
revenue = [22000, 55000, 62000, 75000, 85000]
plt.plot(year, revenue) 
plt.show()

# %% [markdown]
# ## 2 Graphs at the time
# Code to make 2 graphs at the same time

# %%
year = [2010, 2012, 2014, 2016, 2018]
revenue = [22000, 55000, 62000, 75000, 85000]
costs = [30000, 32000, 40000, 50000, 60000]
plt.plot(year, revenue) 
plt.plot(year, costs)
plt.show()

# %% [markdown]
# ## Color and type of line
# In this case we change the type of line and color for the graph

# %%
year = [2010, 2012, 2014, 2016, 2018]
revenue = [22000, 55000, 62000, 75000, 85000]
costs = [30000, 32000, 40000, 50000, 60000]
plt.plot(year, revenue, color='green', linestyle="--")
plt.plot(year, costs, color='red', marker="s")
plt.show()

# %% [markdown]
# ## Labels for the graphs
# Using labels and title to understand easier graphs

# %%
year = [2010, 2012, 2014, 2016, 2018]
revenue = [22000, 55000, 62000, 75000, 85000]
costs = [30000, 32000, 40000, 50000, 60000]
plt.plot(year, revenue, color='green', linestyle="--", marker="o")
plt.plot(year, costs, color='red', marker="s")
plt.axis([2010,2018,22000,85000])
plt.xlabel('Year')
plt.ylabel('Money in usd')
plt.title('Revenue vs Costs in awesome inc')
plt.legend(['Revenue', 'Costs'])
plt.show()

# %% [markdown]
# ## Subplots
# Subplots are independent graphs at once. Below is the code to do it

# %%
year = [2010, 2012, 2014, 2016, 2018]
revenue = [22000, 55000, 62000, 75000, 85000]
costs = [30000, 32000, 40000, 50000, 60000]
plt.subplot(2,1,1) 
plt.plot(year, revenue, color='green', linestyle="--", marker="o")
plt.subplot(2,1,2)
plt.plot(year, costs, color='red', marker="s")
plt.subplots_adjust(bottom=0.2, wspace=0.5)

plt.show()

# %% [markdown]
# ## Graphs with lists using numpy
# To do graphs using functions it is necessary to use the numpy package

# %%
import numpy as np
from matplotlib import pyplot as plt

# evenly sampled time at 200ms intervals from 0 to 5
t = np.arange(0., 5., 0.2)

# Plot 3 graphs at the same time
plt.plot(t, t, t, t**2, t, t**3)
plt.show()

# %% [markdown]
# ## Bars for graphs: Source  https://www.tylervigen.com/view_correlation?id=2956
# To do graphs of bars

# %%
from matplotlib import pyplot as plt

year = ["2000", "2001", "2002", "2003", "2004", "2005"]
money =  [8.2, 7, 6.5, 5.3, 5.2, 4]

plt.bar(range(len(year)), money)

#create your ax object here
ax=plt.subplot()
ax.set_xticks(range(len(year)))
ax.set_xticklabels(year, rotation=50)
plt.legend(['Money spent on pets in billions of dollars'])
plt.show()
# Out:
# C:\Users\Ricardo\Miniconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## Pie chart: Source https://youtu.be/Cr6VqTRO1v0?t=90
# Graph for pie chart

# %%
Topics = ["Linear Algebra", "Statistics", "Calculus", "Algotithms", "Data Preprocessing"]
Percentage = [35, 25, 15, 15, 10]

plt.pie(Percentage,autopct='%0.1f%%')
plt.axis('equal')
plt.legend(Topics)
plt.savefig('mlrequisites.png')
plt.show()
