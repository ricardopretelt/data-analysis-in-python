# %% [markdown]
# # Intro to Python
# ## Hello World strings

# %%
print("Hello world")
# Out:
# Hello world

# %%
Name="Ricardo"
print("Hello "+"Ricardo")
# Out:
# Hello Ricardo

# %% [markdown]
# ## Numbers

# %%
integer=2
float=2.1
print(integer + float)
# Out:
# 4.1

# %% [markdown]
# ## Plus equal

# %%
# Normal plus equal representation
a=2
b=3
a=a+b
print(a)
# Out:
# 5

# %%
# Sum plus equal
a=2
b=3
a+=b
print(a)
# Out:
# 5
